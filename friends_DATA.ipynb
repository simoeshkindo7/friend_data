# %%
import pandas as pd
import numpy as nd

# %%
df = pd.read_csv('C:\\Users\\dell\\Desktop\\New folder\\friends - Sheet1.csv')

# %%
df = pd.DataFrame(df)
df
# Out:
#    Unnamed: 0     fname        lname age_sex section height(cm) weight(kg)  \
# 0           0     Rahul       Pandey    37_M       B      175.4       85.6
# 1           1    Rakesh        Kumar    38_M       B        NaN         xx
# 2           2    Nitesh       Mondol    35_M       B      165.1          ?
# 3           3    Arvind      Dwivedi    40_M       A          0       55.6
# 4           4    Nikhil   Shikharwar    39_M       B      160.8        160
# 5           5  Ashutosh    Merothiya    36_M       A         xx        -60
# 6           6   Shubhro          Das    35_M       C      170.3       75.5
# 7           7   Suvendu          Das    34_M       C      155.1       56.8
# 8           8   Swadesh        Kumar    36_M       C      154.2       60.6
# 9           9      Arun  Vishwakarma    38_M       A      162.1       58.7
#
#    age  spend_A  spend_B spend_C
# 0   37   1500.0    200.0     300
# 1   38      NaN   1000.0     NaN
# 2   35    500.0   -100.0     200
# ...

# %%
#Handling invalid values: 
#There is an invalid value coded as "xx" in the height(cm) column. convert invalid values to "NaN"

# %%
df['height(cm)'] = pd.to_numeric(df['height(cm)'], errors='coerce')

# %%
df
# Out:
#    Unnamed: 0     fname        lname age_sex section  height(cm) weight(kg)  \
# 0           0     Rahul       Pandey    37_M       B       175.4       85.6
# 1           1    Rakesh        Kumar    38_M       B         NaN         xx
# 2           2    Nitesh       Mondol    35_M       B       165.1          ?
# 3           3    Arvind      Dwivedi    40_M       A         0.0       55.6
# 4           4    Nikhil   Shikharwar    39_M       B       160.8        160
# 5           5  Ashutosh    Merothiya    36_M       A         NaN        -60
# 6           6   Shubhro          Das    35_M       C       170.3       75.5
# 7           7   Suvendu          Das    34_M       C       155.1       56.8
# 8           8   Swadesh        Kumar    36_M       C       154.2       60.6
# 9           9      Arun  Vishwakarma    38_M       A       162.1       58.7
#
#    age  spend_A  spend_B spend_C
# 0   37   1500.0    200.0     300
# 1   38      NaN   1000.0     NaN
# ...

# %%
#Split ‘age_sex’ column
#split the 'age_sex' column into two separate columns.

# %%
df_Split = df.copy()

# %%
df_Split[['age','sex']] = df_Split['age_sex'].str.split('_',expand = True)

# %%
df_Split.drop('age_sex',axis=1, inplace=True)

# %%
df_Split
# Out:
#    Unnamed: 0     fname        lname section  height(cm) weight(kg) age  \
# 0           0     Rahul       Pandey       B       175.4       85.6  37
# 1           1    Rakesh        Kumar       B         NaN         xx  38
# 2           2    Nitesh       Mondol       B       165.1          ?  35
# 3           3    Arvind      Dwivedi       A         0.0       55.6  40
# 4           4    Nikhil   Shikharwar       B       160.8        160  39
# 5           5  Ashutosh    Merothiya       A         NaN        -60  36
# 6           6   Shubhro          Das       C       170.3       75.5  35
# 7           7   Suvendu          Das       C       155.1       56.8  34
# 8           8   Swadesh        Kumar       C       154.2       60.6  36
# 9           9      Arun  Vishwakarma       A       162.1       58.7  38
#
#    spend_A  spend_B spend_C sex
# 0   1500.0    200.0     300   M
# 1      NaN   1000.0     NaN   M
# 2    500.0   -100.0     200   M
# 3    300.0    300.0     NaN   M
# ...

# %%
#Reorder the column labels

# %%
df_Reorder = df_Split.copy()

# %%
df_Reorder = df_Reorder[['Unnamed: 0','fname','lname','section','height(cm)','weight(kg)','age','sex','spend_A','spend_B','spend_C',]]

# %%
df_Reorder
# Out:
#    Unnamed: 0     fname        lname section  height(cm) weight(kg) age sex  \
# 0           0     Rahul       Pandey       B       175.4       85.6  37   M
# 1           1    Rakesh        Kumar       B         NaN         xx  38   M
# 2           2    Nitesh       Mondol       B       165.1          ?  35   M
# 3           3    Arvind      Dwivedi       A         0.0       55.6  40   M
# 4           4    Nikhil   Shikharwar       B       160.8        160  39   M
# 5           5  Ashutosh    Merothiya       A         NaN        -60  36   M
# 6           6   Shubhro          Das       C       170.3       75.5  35   M
# 7           7   Suvendu          Das       C       155.1       56.8  34   M
# 8           8   Swadesh        Kumar       C       154.2       60.6  36   M
# 9           9      Arun  Vishwakarma       A       162.1       58.7  38   M
#
#    spend_A  spend_B spend_C
# 0   1500.0    200.0     300
# 1      NaN   1000.0     NaN
# 2    500.0   -100.0     200
# ...
